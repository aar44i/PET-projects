# %%
import requests
import time

# %%
 from owslib.wcs import WebCoverageService

wcs = WebCoverageService('https://maps.isric.org/mapserv?map=/map/soc.map',
                         version='2.0.1')

# %%
print(wcs.contents.keys())
# Out:
# dict_keys(['soc_0-5cm_Q0.5', 'soc_0-5cm_Q0.05', 'soc_0-5cm_Q0.95', 'soc_0-5cm_mean', 'soc_0-5cm_uncertainty', 'soc_5-15cm_Q0.05', 'soc_5-15cm_Q0.5', 'soc_5-15cm_Q0.95', 'soc_5-15cm_mean', 'soc_5-15cm_uncertainty', 'soc_15-30cm_Q0.5', 'soc_15-30cm_Q0.05', 'soc_15-30cm_Q0.95', 'soc_15-30cm_mean', 'soc_15-30cm_uncertainty', 'soc_30-60cm_Q0.05', 'soc_30-60cm_Q0.5', 'soc_30-60cm_Q0.95', 'soc_30-60cm_mean', 'soc_30-60cm_uncertainty', 'soc_60-100cm_Q0.05', 'soc_60-100cm_Q0.5', 'soc_60-100cm_Q0.95', 'soc_60-100cm_mean', 'soc_60-100cm_uncertainty', 'soc_100-200cm_Q0.05', 'soc_100-200cm_Q0.5', 'soc_100-200cm_Q0.95', 'soc_100-200cm_mean', 'soc_100-200cm_uncertainty'])

# %%
 cov_id = 'soc_0-5cm_mean'
ph_0_5 = wcs.contents[cov_id]
ph_0_5.supportedFormats
# Out:
# ['image/tiff',
#  'image/png',
#  'image/jpeg',
#  'image/png; mode=8bit',
#  'image/vnd.jpeg-png',
#  'image/vnd.jpeg-png8']

# %% [markdown]
# subsets = [('X',  -2784000, 800000), ('Y', 156000, 3863000)] Гвинейский залив

# %% [markdown]
# subsets = [('X',  -584000, 3000000), ('Y', 156000, 3863000)] Сахара

# %% [markdown]
# subsets = [('X', -800000, 3000000), ('Y', 4000000, 7700000)] Европа

# %% [markdown]
# subsets = [('X', 1000000, 5000000), ('Y', 4000000, 7700000)]  Чуть ближе к россии

# %% [markdown]
# subsets = [('X', 3000000, 7000000), ('Y', 4000000, 7700000)] Россия!

# %%
try:
#  subsets = [('X', -1784000, -1140000), ('Y', 1356000, 1863000)] #original
    subsets = [('X', 3000000, 7000000), ('Y', 4000000, 7700000)] 

    crs = "http://www.opengis.net/def/crs/EPSG/0/152160"
    # crs = "http://www.opengis.net/def/crs/EPSG/0/4326"

    response = wcs.getCoverage(
        identifier=[cov_id], 
        crs=crs,
        subsets=subsets, 
        resx=250, resy=250, 
        format=ph_0_5.supportedFormats[0])

    with open('C:/Users/gorba/DataSciense/PET-projects/SoilGrid/Soil_organic.tif', 'wb') as file:
        file.write(response.read())

    import rasterio
    from rasterio import plot

    ph = rasterio.open('C:/Users/gorba/DataSciense/PET-projects/SoilGrid/Soil_organic.tif', driver="GTiff")
    # %matplotlib inline
    plot.show(ph, cmap='gist_ncar')
except requests.exceptions.ReadTimeout:
        print("\n Переподключение к серверам\n")
        time.sleep(30)
