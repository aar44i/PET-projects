# %%
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.tsa.api import ExponentialSmoothing, Holt
from pylab import rcParams
rcParams['figure.figsize'] = 20, 5

# %%
df = pd.read_csv('C:/Users/gorba/Desktop/Univercity/1 mag/Гидрология материков Гречушникова/уклон.txt', sep = '\t')
df = df.rename(columns={'Graphic Profile 1': 'Y'})

# %%
df
# Out:
#              X     Y
# 0     0.000000    11
# 1     0.000826    10
# 2     0.001651     7
# 3     0.002477     7
# 4     0.003302     8
# ...        ...   ...
# 8543  7.083279  2936
# 8544  7.084107  2951
# 8545  7.084936  2974
# 8546  7.085765  2988
# 8547  7.086594  2983
#
# [8548 rows x 2 columns]

# %%
plt.plot(df)

# %%
fit  = Holt(df['Y']).fit()
plt.plot(fit.fittedvalues[1:1000])

# %%
rollingseries = df.rolling(window = 50)
rollingmean = rollingseries.mean()
# rollingmean[1:1000].plot()
rollingmean.plot()
# plt.plot(rollingmean['X'], rollingmean['Y'])
# plt.plot(7000, 1000, label = "line 1")
plt.show()

# %%
rollingmean.to_excel('C:/Users/gorba/Desktop/Univercity/1 mag/Гидрология материков Гречушникова/уклон_smooth.xlsx')
