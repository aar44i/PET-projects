# %%
import pandas as pd
import cloupy as cl
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
df = pd.read_excel('df_total_correct.xlsx')
df = df.groupby(by="Dot").mean()
df.drop(columns=['Unnamed: 0'], inplace = True)
df.reset_index(inplace=True)
df['Dot'] = df['Dot'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
df.sort_values(by=['Dot'], inplace=True)
df
# Out:
#     Dot   latitude  longitude   chamber_p  chamber_p_t  chamber_t  soil_t  \
# 0     1  44.578892  37.973507  100.515924    35.678520  27.589426  9999.0
# 8     2  44.579172  37.973155  100.414531    41.690700  29.677498  9999.0
# 9     3  44.579778  37.972122  100.345971    41.127518  29.416013  9999.0
# 10    4  44.580047  37.971510  100.226584    40.336947  28.862218  9999.0
# 11    5  44.579575  37.971497  100.266129    41.164208  33.866318  9999.0
# 12    6  44.579103  37.970840  100.377405    42.065673  31.192630  9999.0
# 13    7  44.578535  37.972705  100.556407    41.616012  36.222452  9999.0
# 14    8  44.579208  37.972178  100.368810    42.224560  33.703434  9999.0
# 15    9  44.579027  37.971398  100.397437    41.866676  30.574341  9999.0
# 1    10  44.578535  37.972178  101.173048    43.055755  37.085275  9999.0
# 2    11  44.578080  37.972560  100.660119    43.359982  30.751114  9999.0
# 3    12  44.577940  37.971585  100.656836    43.730927  35.767921  9999.0
# 4    13  44.578238  37.970863  100.569612    43.172519  35.398812  9999.0
# 5    14  44.577100  37.971697  100.794133    42.772910  34.654551  9999.0
# 6    15  44.577613  37.971007  100.754374    43.028233  34.428466  9999.0
# 7    16  44.578033  37.970330  100.637898    42.360437  32.758188  9999.0
#
#      soilp_c   soilp_m    soilp_t          ch4         co2        h2o  \
# 0   0.005000  0.050476  27.471429  2013.109643  471.938276  22.190107
# 8   0.019807  0.153314  32.879048  2002.724571  480.851279  24.013034
# 9   0.020528  0.162413  30.691619  2005.336952  467.922745  22.442795
# 10  0.007562  0.073495  29.947143  2002.574143  447.907155  21.006345
# 11  0.015898  0.128557  31.339113  2001.837969  455.739324  21.215942
# 12  0.009221  0.089807  33.297143  1999.718881  462.893576  22.165510
# 13  0.016507  0.141043  34.567619  2007.010119  466.074657  23.026714
# 14  0.015076  0.116752  32.887857  2001.353340  462.431107  21.388818
# 15  0.012895  0.106962  32.843104  2001.792174  449.723962  21.701896
# 1   0.005000  0.056000  37.119048  1995.894381  441.951029  12.440330
# 2   0.013340  0.123336  35.135238  1997.119119  448.897062  20.874189
# 3   0.010555  0.102088  36.567857  2007.253881  466.516476  19.496193
# 4   0.008510  0.085755  36.331429  2000.869905  461.132802  22.145651
# 5   0.011476  0.102930  35.468571  1996.789238  452.414876  21.017832
# 6   0.008500  0.086086  36.601905  1999.094286  453.250183  18.632834
# 7   0.011850  0.107721  35.577381  1999.359238  452.210819  20.328548
#
#          err
# 0   0.323810
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  1.619048
# 14  0.000000
# 15  0.000000
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.000000

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
bound = gpd.read_file('Gel_bound.shp')
ax = bound.plot(color='white', edgecolor='black')
gdf.plot(ax=ax, color='red')

for x, y, label in zip(df.longitude, df.latitude, df.Dot): # Номера точек
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points")

# %% [markdown]
# # CH4

# %%
df_clean =  df.iloc[:, [10, 2, 1]]
df_clean = df_clean.to_numpy()

# %%
df_clean
# Out:
# array([[2013.10964286,   37.9735075 ,   44.5788925 ],
#        [2002.72457143,   37.973155  ,   44.5791725 ],
#        [2005.33695238,   37.972122  ,   44.579778  ],
#        [2002.57414286,   37.97151   ,   44.5800475 ],
#        [2001.83796945,   37.9714975 ,   44.579575  ],
#        [1999.71888095,   37.97084   ,   44.5791025 ],
#        [2007.01011905,   37.972705  ,   44.578535  ],
#        [2001.35334043,   37.9721775 ,   44.5792075 ],
#        [2001.79217422,   37.9713975 ,   44.5790275 ],
#        [1995.89438095,   37.9721775 ,   44.578535  ],
#        [1997.11911905,   37.97256   ,   44.57808   ],
#        [2007.25388095,   37.971585  ,   44.57794   ],
#        [2000.86990476,   37.9708625 ,   44.5782375 ],
#        [1996.7892381 ,   37.97169667,   44.5771    ],
#        [1999.09428571,   37.9710075 ,   44.5776125 ],
#        [1999.3592381 ,   37.97033   ,   44.5780325 ]])

# %%
Long = df_clean[:,1]; Lat = df_clean[:,2]; Elev = df_clean[:,0]; #Variables
pts=1000000; #Input the desired number of points here

# %%
[x,y]=np.meshgrid(np.linspace(np.min(Long),np.max(Long),10000),np.linspace(np.min(Lat),np.max(Lat),10000));
z = griddata((Long, Lat), Elev, (x, y), method='cubic'); # nearest, cubic
x = np.matrix.flatten(x); #Gridded longitude
y = np.matrix.flatten(y); #Gridded latitude
z = np.matrix.flatten(z); #Gridded elevation
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-151-da48fe34ca71> in <module>
# ----> 1 [x,y]=np.meshgrid(np.linspace(np.min(Long),np.max(Long),10000),np.linspace(np.min(Lat),np.max(Lat),10000));
#       2 z = griddata((Long, Lat), Elev, (x, y), method='cubic'); # nearest, cubic
#       3 x = np.matrix.flatten(x); #Gridded longitude
#       4 y = np.matrix.flatten(y); #Gridded latitude
#       5 z = np.matrix.flatten(z); #Gridded elevation
#
# ~\anaconda3\lib\site-packages\numpy\core\overrides.py in meshgrid(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in meshgrid(copy, sparse, indexing, *xi)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in <listcomp>(.0)
#
# MemoryError: Unable to allocate 763. MiB for an array with shape (10000, 10000) and data type float64

# %%
plt.scatter(x,y,1,z)
plt.colorbar(label='Ch4')
plt.xlabel('Longitude [°]')
plt.ylabel('Latitude [°]')

# %%
grid_x, grid_y = np.meshgrid[0:1:100, 0:1:200]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-dcd5fc3b5849> in <module>
# ----> 1 grid_x, grid_y = np.meshgrid[0:1:100, 0:1:200]
#
# TypeError: 'function' object is not subscriptable

# %%
z = griddata((Long, Lat), Elev, (grid_x, grid_y), method='nearest')
x = np.matrix.flatten(grid_x); #Gridded longitude
y = np.matrix.flatten(grid_y); #Gridded latitude
z = np.matrix.flatten(z); #Gridded elevation

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,1,z)
plt.colorbar(label='Elevation above sea level [m]')
plt.xlabel('Longitude [°]')
plt.ylabel('Latitude [°]')
# Out:
# Text(0, 0.5, 'Latitude [°]')
