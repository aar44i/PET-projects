# %%
import pandas as pd
import numpy as np
from numpy import int32
from datetime import datetime, timedelta

# %%
data = pd.read_excel('julian_data.xlsx')

# %%
df = data.copy()

# %%
df.rename(columns={"Unnamed: 44": "datetime"}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4996 entries, 0 to 4995
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Julian Day                     4996 non-null   float64
#  1   Chamber Number                 4996 non-null   int64
#  2   Measurement Duration (s)       4996 non-null   int64
#  3   Deadband Start (pts)           4996 non-null   int64
#  4   Deadband End (pts)             4996 non-null   int64
#  5           Mean CO2 (ppm)         4996 non-null   float64
#  6           Mean CH4 (ppm)         4996 non-null   float64
#  7           Mean N2O (ppm)         4996 non-null   float64
#  8           Mean NH3 (ppm)         4996 non-null   float64
#  9           Mean H2O (percent)     4996 non-null   float64
#  10       Chem Detect (0/1)         4996 non-null   float64
#  11     Cav. Pressure (kPa)         4996 non-null   float64
# ...

# %%
# df['int_date'] = int(df['Julian Day'])
df['int_date'] = df['Julian Day'].astype(int)

# %%
df.sample(5)
# Out:
#       Julian Day  Chamber Number  Measurement Duration (s)  \
# 4721  251.522546               7                       693
# 2570  219.358542               8                       693
# 1500  207.481146               2                       692
# 4035  244.314410               5                       695
# 4084  244.825208               9                       693
#
#       Deadband Start (pts)  Deadband End (pts)          Mean CO2 (ppm)  \
# 4721                    39                   1              490.135107
# 2570                    39                   1              486.791886
# 1500                    39                   1              442.446930
# 4035                    39                   1              492.023136
# 4084                    39                   1              523.068602
#
#               Mean CH4 (ppm)          Mean N2O (ppm)          Mean NH3 (ppm)  \
# 4721                2.079330                0.164818               13.216600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4996 entries, 0 to 4995
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Julian Day                     4996 non-null   float64
#  1   Chamber Number                 4996 non-null   int64
#  2   Measurement Duration (s)       4996 non-null   int64
#  3   Deadband Start (pts)           4996 non-null   int64
#  4   Deadband End (pts)             4996 non-null   int64
#  5           Mean CO2 (ppm)         4996 non-null   float64
#  6           Mean CH4 (ppm)         4996 non-null   float64
#  7           Mean N2O (ppm)         4996 non-null   float64
#  8           Mean NH3 (ppm)         4996 non-null   float64
#  9           Mean H2O (percent)     4996 non-null   float64
#  10       Chem Detect (0/1)         4996 non-null   float64
#  11     Cav. Pressure (kPa)         4996 non-null   float64
# ...

# %%
df.head()
# Out:
#    Julian Day  Chamber Number  Measurement Duration (s)  Deadband Start (pts)  \
# 0  174.552963               1                      2226                    39
# 1  174.595706               1                       695                    39
# 2  174.605104               2                       695                    39
# 3  174.614502               3                       695                    39
# 4  174.624016               4                       693                    39
#
#    Deadband End (pts)          Mean CO2 (ppm)          Mean CH4 (ppm)  \
# 0                   1              427.205409                2.015021
# 1                   1              597.435564                2.009837
# 2                   1              648.909945                2.011832
# 3                   1              638.593568                2.010531
# 4                   1              560.740119                2.013847
#
# ...

# %%
for i in range(len(df)):
    if df['int_date'].loc[i+1] != df['int_date'].loc[i]:
        df['datetime'].loc[i+1] = df['datetime'].loc[i] + timedelta(days = int(df['int_date'].loc[i+1] - df['int_date'].loc[i]))
    else:
        df['datetime'].loc[i+1] = df['datetime'].loc[i]

# %%
# df.to_excel('all_with_data.xlsx')

# %%
df_group = df.groupby([df['datetime'].dt.date]).mean()

# %%
df_group.to_excel('all_with_data_gro.xlsx')
