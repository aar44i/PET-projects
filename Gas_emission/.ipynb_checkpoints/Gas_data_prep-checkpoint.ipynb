# %%
import pandas as pd
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
df_1 = pd.read_excel(open('gas_model_fulldata.xlsx', 'rb'), sheet_name='1')
df_2 = pd.read_excel(open('gas_model_fulldata.xlsx', 'rb'), sheet_name='2')
df_3 = pd.read_excel(open('gas_model_fulldata.xlsx', 'rb'), sheet_name='3')
df_4 = pd.read_excel(open('gas_model_fulldata.xlsx', 'rb'), sheet_name='4')

# %% [markdown]
# # df_1 + df_2

# %%
df_1 = df_1.interpolate()

# %%
df_1['datetime'] = pd.to_datetime(df_1['Date'] + df_1['Time'], format='%Y-%m-%d%H:%M:%S')
df_2['datetime'] = pd.to_datetime(df_2['date'] + df_2['time'], format='%Y-%m-%d%H:%M')

# %%
df_1_2 = pd.merge(df_1, df_2, on=["datetime"], how='inner')

# %% [markdown]
# # df_3

# %%
df_3.columns = df_3.iloc[0]
df_3.drop(df_3.index[[0,1]], inplace = True)
df_3
# Out:
# 0                           filename  date Month Day daytime air_molar_volume  \
# 2     2022-05-11T000000_AIU-2343.ghg  2022    05  11       0     0.236947E-01
# 3                    not_enough_data  2022    05  11   -9999            -9999
# 4     2022-05-11T010000_AIU-2343.ghg  2022    05  11       0     0.236717E-01
# 5     2022-05-11T013000_AIU-2343.ghg  2022    05  11       0     0.236777E-01
# 6     2022-05-11T020000_AIU-2343.ghg  2022    05  11       0     0.236924E-01
# ...                              ...   ...   ...  ..     ...              ...
# 4483  2022-08-12T083000_AIU-2343.ghg  2022    08  12       1     0.255062E-01
# 4484  2022-08-12T090000_AIU-2343.ghg  2022    08  12       1     0.256307E-01
# 4485  2022-08-12T093000_AIU-2343.ghg  2022    08  12       1     0.256862E-01
# 4486  2022-08-12T100000_AIU-2343.ghg  2022    08  12       1     0.257447E-01
# 4487  2022-08-12T103000_AIU-2343.ghg  2022    08  12       1     0.258553E-01
#
# 0           e wind_speed max_wind_speed wind_dir        u*
# 2     968.552   0.234039        2.49742  53.0498  0.195922
# 3       -9999      -9999          -9999    -9999     -9999
# 4     742.326   0.829133        2.88472  326.316  0.134331
# 5     727.909   0.340054        2.80909  140.988  0.240781
# 6     669.809    1.47261        5.58247  49.6942  0.143896
# ...       ...        ...            ...      ...       ...
# 4483  2203.81   0.700584        2.45816  150.571   0.25883
# 4484  2088.91    1.03271        3.37999  138.592  0.219127
# 4485  2139.62   0.657459        3.34711  208.930  0.388367
# 4486  2224.22    1.56840        7.75004  105.818  0.264456
# 4487  2165.85    1.13931        4.48131  108.450  0.398411
#
# [4486 rows x 11 columns]

# %%
df_3['datetime'] = pd.to_datetime(df_3['date'] + df_3['Month'] + df_3['Day'], format='%Y-%m-%d')

# %%
df_3.reset_index(drop=True, inplace=True)
# Out:
# 0                           filename  date Month Day daytime air_molar_volume  \
# 0     2022-05-11T000000_AIU-2343.ghg  2022    05  11       0     0.236947E-01
# 1                    not_enough_data  2022    05  11   -9999            -9999
# 2     2022-05-11T010000_AIU-2343.ghg  2022    05  11       0     0.236717E-01
# 3     2022-05-11T013000_AIU-2343.ghg  2022    05  11       0     0.236777E-01
# 4     2022-05-11T020000_AIU-2343.ghg  2022    05  11       0     0.236924E-01
# ...                              ...   ...   ...  ..     ...              ...
# 4481  2022-08-12T083000_AIU-2343.ghg  2022    08  12       1     0.255062E-01
# 4482  2022-08-12T090000_AIU-2343.ghg  2022    08  12       1     0.256307E-01
# 4483  2022-08-12T093000_AIU-2343.ghg  2022    08  12       1     0.256862E-01
# 4484  2022-08-12T100000_AIU-2343.ghg  2022    08  12       1     0.257447E-01
# 4485  2022-08-12T103000_AIU-2343.ghg  2022    08  12       1     0.258553E-01
#
# 0           e wind_speed max_wind_speed wind_dir        u*   datetime
# 0     968.552   0.234039        2.49742  53.0498  0.195922 2022-05-11
# 1       -9999      -9999          -9999    -9999     -9999 2022-05-11
# 2     742.326   0.829133        2.88472  326.316  0.134331 2022-05-11
# 3     727.909   0.340054        2.80909  140.988  0.240781 2022-05-11
# 4     669.809    1.47261        5.58247  49.6942  0.143896 2022-05-11
# ...       ...        ...            ...      ...       ...        ...
# 4481  2203.81   0.700584        2.45816  150.571   0.25883 2022-08-12
# 4482  2088.91    1.03271        3.37999  138.592  0.219127 2022-08-12
# 4483  2139.62   0.657459        3.34711  208.930  0.388367 2022-08-12
# 4484  2224.22    1.56840        7.75004  105.818  0.264456 2022-08-12
# 4485  2165.85    1.13931        4.48131  108.450  0.398411 2022-08-12
#
# [4486 rows x 12 columns]

# %%
for i in range(len(df_3)):
    df_3['datetime'][i+1] = (df_3['datetime'][i] + timedelta(minutes=30)).strftime('%Y-%m-%d %H:%M')

# %%
df_1_2_3 = pd.merge(df_1_2, df_3, on=["datetime"], how='inner')

# %% [markdown]
# # df_4

# %%
df_4
# Out:
#         UNIXTIME        Дата     Время  Напр АКБ  Температура логгера  \
# 0     1651928400  07.05.2022  16:00:00     12.33                23.76
# 1     1651935600  07.05.2022  18:00:00     12.33                23.80
# 2     1652097600  09.05.2022  15:00:00     13.63                22.37
# 3     1652101200  09.05.2022  16:00:00     13.65                22.51
# 4     1652104800  09.05.2022  17:00:00     13.60                21.08
# ...          ...         ...       ...       ...                  ...
# 2862  1662393600  05.09.2022  19:00:00     13.82                13.30
# 2863  1662397200  05.09.2022  20:00:00     13.82                13.28
# 2864  1662400800  05.09.2022  21:00:00     13.82                13.56
# 2865  1662404400  05.09.2022  22:00:00     13.82                13.90
# 2866  1662408000  05.09.2022  23:00:00     13.82                14.24
#
#       Отн. влажность  Точка росы  Осадки  Температура воздуха  \
# 0              47.64       12.16    0.00                  NaN
# 1              48.20       12.10    0.00                  NaN
# 2              30.27        1.47    0.00                  NaN
# 3              30.17        1.41    0.00                  NaN
# 4              33.58        2.34    0.00                  NaN
# ...              ...         ...     ...                  ...
# 2862           91.82       11.84    0.25                13.13
# 2863           90.64       11.99    0.25                13.48
# 2864           90.83       12.39    0.25                13.85
# 2865           90.67       12.64    0.25                14.13
# 2866           90.69       12.94    0.25                14.43
#
#       Атмосферное давление  Скорость ветра Направление ветра  \
# 0                   754.37            0.00             Север
# 1                   754.60            0.00             Север
# 2                   750.87            6.93      северо-запад
# 3                   750.83            6.90             Запад
# 4                   750.86            5.27             Запад
# ...                    ...             ...               ...
# 2862                752.75            0.61      северо-запад
# 2863                752.86            0.14         юго-запад
# 2864                752.54            0.49         юго-запад
# 2865                752.38            0.84         юго-запад
# 2866                752.42            1.09         юго-запад
#
#       Приходящая солнечная радиация  Влагосодержание почвы  \
# 0                               NaN                   0.00
# 1                               NaN                   0.00
# 2                            576.57                   0.00
# 3                            420.45                  29.53
# 4                            215.58                  39.60
# ...                             ...                    ...
# 2862                           0.00                   6.30
# 2863                           0.00                   6.25
# 2864                           0.00                   6.24
# 2865                           0.00                   6.22
# 2866                           0.00                   6.18
#
#       Электропроводность почвы  Температура почвы
# 0                         0.00              23.70
# 1                         0.00              23.80
# 2                         0.00              21.13
# 3                         0.57              18.63
# 4                         0.76              16.25
# ...                        ...                ...
# 2862                      0.00              26.16
# 2863                      0.00              25.80
# 2864                      0.00              25.52
# 2865                      0.00              25.29
# 2866                      0.00              25.08
#
# [2867 rows x 16 columns]

# %%
df_4['datetime'] = pd.to_datetime(df_4['Дата'] + df_4['Время'], format=  '%d.%m.%Y%H:%M:%S')

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2867 entries, 0 to 2866
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   UNIXTIME                       2867 non-null   int64
#  1   Дата                           2867 non-null   object
#  2   Время                          2867 non-null   object
#  3   Напр АКБ                       2867 non-null   float64
#  4   Температура логгера            2867 non-null   float64
#  5   Отн. влажность                 2867 non-null   float64
#  6   Точка росы                     2867 non-null   float64
#  7   Осадки                         2867 non-null   float64
#  8   Температура воздуха            2833 non-null   float64
#  9   Атмосферное давление           2867 non-null   float64
#  10  Скорость ветра                 2867 non-null   float64
#  11  Направление ветра              2867 non-null   object
#  12  Приходящая солнечная радиация  2865 non-null   float64
#  13  Влагосодержание почвы          2867 non-null   float64
#  14  Электропроводность почвы       2867 non-null   float64
#  15  Температура почвы              2867 non-null   float64
#  16  datetime                       2867 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(12), int64(1), object(3)
# memory usage: 380.9+ KB

# %%
df_4_columns = df_4.columns.values.tolist()

# %%
unwanted_num = ['UNIXTIME', 'Дата', 'Время', 'Направление ветра', 'datetime']

# %%
df_4_columns = [elem for elem in df_4_columns if elem not in unwanted_num]

# %%
df_4_columns
# Out:
# ['Напр АКБ',
#  'Температура логгера',
#  'Отн. влажность',
#  'Точка росы',
#  'Осадки',
#  'Температура воздуха',
#  'Атмосферное давление',
#  'Скорость ветра',
#  'Приходящая солнечная радиация',
#  'Влагосодержание почвы',
#  'Электропроводность почвы',
#  'Температура почвы']

# %%
df_1_4= pd.merge(df_1_2_3, df_4, on=["datetime"], how='left')

# %%
df_1_4[df_4_columns] = df_1_4[df_4_columns].interpolate()

# %%
df_1_4
# Out:
#             Date      Time  NEE_f потокСО2 (таргет)  \
# 0     2022-05-12  00:30:00                 2.100000
# 1     2022-05-12  01:00:00                 2.610000
# 2     2022-05-12  01:30:00                 3.410000
# 3     2022-05-12  02:00:00                 3.140000
# 4     2022-05-12  02:30:00                 2.810000
# ...          ...       ...                      ...
# 4411  2022-08-11  22:00:00                 3.238182
# 4412  2022-08-11  22:30:00                 3.870000
# 4413  2022-08-11  23:00:00                 2.896471
# 4414  2022-08-11  23:30:00                 8.110000
# 4415  2022-08-12  00:00:00                 3.080625
#
#       LE_f скрытое тепло (испарение)  H_f (скрытое тепло)  \
# 0                             17.530            -6.540000
# 1                             19.670            -7.120000
# 2                             13.460            -7.520000
# 3                             12.570           -11.760000
# 4                              8.100            -6.380000
# ...                              ...                  ...
# 4411                          -7.642            -4.114167
# 4412                          14.730           -15.140000
# 4413                          -4.270           -11.233889
# 4414                           2.020            -8.060000
# 4415                         -41.440            -9.340000
#
#       Rg_f (суммарная радиация)  VPD_f (дефицит водяного пара)  \
# 0                           0.0                           5.05
# 1                           0.0                           4.86
# 2                           0.0                           4.71
# 3                           0.0                           4.21
# 4                           0.0                           3.86
# ...                         ...                            ...
# 4411                        0.0                          16.34
# 4412                        0.0                          18.29
# 4413                        0.0                          17.80
# 4414                        0.0                          16.99
# 4415                        0.0                          16.03
#
#       rH_f (относительная влажность)  Tair_f   Tsoil_f  ...  Точка росы  \
# 0                              64.72    12.37    16.17  ...         NaN
# 1                              65.76    12.23    15.99  ...       6.130
# 2                              66.58    12.12    15.81  ...       6.235
# 3                              69.30    11.71    15.71  ...       6.340
# 4                              71.41    11.48    15.53  ...       6.480
# ...                              ...      ...      ...  ...         ...
# 4411                           59.92    29.35    29.10  ...      18.030
# 4412                           54.55    29.12    28.99  ...      17.795
# 4413                           53.64    28.32    28.89  ...      17.560
# 4414                           54.67    27.90    28.77  ...      17.835
# 4415                           56.11    27.46    28.63  ...      18.110
#
#       Осадки  Температура воздуха  Атмосферное давление Скорость ветра  \
# 0        NaN                  NaN                   NaN            NaN
# 1        0.0               11.580               754.440          2.600
# 2        0.0               11.380               754.515          2.340
# 3        0.0               11.180               754.590          2.080
# 4        0.0               11.115               754.620          1.575
# ...      ...                  ...                   ...            ...
# 4411     0.0               27.310               745.460          1.590
# 4412     0.0               26.565               745.515          1.230
# 4413     0.0               25.820               745.570          0.870
# 4414     0.0               25.085               745.605          0.700
# 4415     0.0               24.350               745.640          0.530
#
#      Направление ветра Приходящая солнечная радиация  Влагосодержание почвы  \
# 0                  NaN                           NaN                    NaN
# 1            юго-запад                           0.0                 38.710
# 2                  NaN                           0.0                 38.675
# 3            юго-запад                           0.0                 38.640
# 4                  NaN                           0.0                 38.605
# ...                ...                           ...                    ...
# 4411            Восток                           0.0                  9.730
# 4412               NaN                           0.0                  9.675
# 4413            Восток                           0.0                  9.620
# 4414               NaN                           0.0                  9.600
# 4415        юго-восток                           0.0                  9.580
#
#       Электропроводность почвы  Температура почвы
# 0                          NaN                NaN
# 1                        0.730              16.07
# 2                        0.725              15.94
# 3                        0.720              15.81
# 4                        0.720              15.70
# ...                        ...                ...
# 4411                     0.030              32.22
# 4412                     0.030              31.96
# 4413                     0.030              31.70
# 4414                     0.030              31.45
# 4415                     0.030              31.20
#
# [4416 rows x 60 columns]

# %%
df_1_4.to_excel('gas_model_data_convert.xlsx')
